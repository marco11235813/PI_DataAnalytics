# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %load_ext autoreload
# %autoreload 2
import resources

import warnings
warnings.filterwarnings(action= 'ignore')

# %%
df_unido = pd.read_parquet('../data/df_unido.parquet')

# %% [markdown]
# # ANALISIS PRELIMINAR DE CARACTERISTICAS GENERALES

# %% [markdown]
# Veamos las caracteristicas generales de nuestro dataset para realizar una primera aproximacion a los datos con una vision global, para nuestro posterior estudio

# %%
resources.informe_dataframe(df_unido)
# Out:
# INFORME PRELIMINAR SOBRE CARACTERISTICAS DEL DATASET:
#
# --Dimensiones del DataFrame--
# Filas: 696
# Columnas: 16
#
# --Numero de datos--
# 11136
#
# --Filas y Columnas--
# Filas: muestra de indices-------> [0, 1, 2, 3, 4]  -----> Desde 0  Hasta 695
# Columnas: ['ID_hecho', 'FECHA', 'ROL', 'VEHICULO_FALLECIDO', 'SEXO', 'EDAD', 'N_VICTIMAS', 'HORA_HECHO', 'TIPO_DE_CALLE', 'CRUCE', 'COMUNA', 'LONGITUD', 'LATITUD', 'PARTICIPANTES', 'VICTIMA', 'ACUSADO']
#
# --Estadisticos preliminares generales--
#              EDAD  N_VICTIMAS  HORA_HECHO    LONGITUD     LATITUD
# count  696.000000  696.000000  696.000000  696.000000  696.000000
# mean    42.366379    1.030172   11.650862  -58.189284  -34.470381
# std     19.087213    0.179393    6.687060    3.831615    2.269899
# min      1.000000    1.000000    0.000000  -58.533256  -34.760959
# 25%     28.000000    1.000000    6.000000  -58.476178  -34.643689
# 50%     39.000000    1.000000   11.000000  -58.443843  -34.622866
# ...

# %% [markdown]
# Tipos de Variables

# %%
df_unido.dtypes
# Out:
# ID_hecho                      object
# FECHA                 datetime64[ns]
# ROL                           object
# VEHICULO_FALLECIDO            object
# SEXO                          object
# EDAD                           int32
# N_VICTIMAS                     int32
# HORA_HECHO                     int32
# TIPO_DE_CALLE                 object
# CRUCE                         object
# COMUNA                        object
# LONGITUD                     float64
# LATITUD                      float64
# PARTICIPANTES                 object
# VICTIMA                       object
# ACUSADO                       object
# dtype: object

# %% [markdown]
# ## Por columna

# %% [markdown]
# ### Columna FECHA

# %%
resources.informe_columna(df_unido, 'FECHA')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE FECHA:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 598
#
# --Valores unicos en la columna--
# Ej: ['2016-01-01' '2016-01-02' '2016-01-03']  -----> Desde 2016-01-01  Hasta 2021-12-15
#
# --Moda de la columna especificada--
# Valor modal -----> 2018-12-18 00:00:00
# Frecuencia acumulada ------> 3
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  2018-12-18    3
# 2016-02-17    3
# 2018-12-12    3
# Name: FECHA, dtype: int64
#
# --Valor maximo y minimo--
# Maximo: 2021-12-30 00:00:00
# Minimo: 2016-01-01 00:00:00

# %% [markdown]
# ### Columna ROL

# %%
resources.informe_columna(df_unido, 'ROL')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE ROL:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 5
#
# --Valores unicos en la columna--
# ['CONDUCTOR' 'PASAJERO_ACOMPAÑANTE' 'PEATON' 'SD' 'CICLISTA']
#
# --Moda de la columna especificada--
# Valor modal -----> CONDUCTOR
# Frecuencia acumulada ------> 324
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  CONDUCTOR               324
# PEATON                  265
# PASAJERO_ACOMPAÑANTE     67
# Name: ROL, dtype: int64

# %% [markdown]
# ### Columna VEHICULO_FALLECIDO

# %%
resources.informe_columna(df_unido, 'VEHICULO_FALLECIDO')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE VEHICULO_FALLECIDO:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 8
#
# --Valores unicos en la columna (Primeros 5 valores)--
# ['MOTO' 'AUTO' 'PEATON' 'SD' 'CARGAS']
#
# --Moda de la columna especificada--
# Valor modal -----> MOTO
# Frecuencia acumulada ------> 295
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  MOTO      295
# PEATON    265
# AUTO       84
# Name: VEHICULO_FALLECIDO, dtype: int64

# %% [markdown]
# ### Columna SEXO

# %%
resources.informe_columna(df_unido, 'SEXO')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE SEXO:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 2
#
# --Valores unicos en la columna--
# ['MASCULINO' 'FEMENINO']
#
# --Moda de la columna especificada--
# Valor modal -----> MASCULINO
# Frecuencia acumulada ------> 532
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  MASCULINO    532
# FEMENINO     164
# Name: SEXO, dtype: int64

# %% [markdown]
# ### Columna HORA_HECHO

# %%
resources.informe_columna(df_unido, 'HORA_HECHO')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE HORA_HECHO:
#
# --Numero de datos nulos--
# 0
#
# --Valores unicos en la columna--
# Ej: [4 1 7 0 5]  -----> Desde 4  Hasta 13
#
# --Estadisticos Principales de la columna--
# Media: 11.65
# Desviacion Estandar: 6.69
# Primer cuartil: 6.0
# Mediana: 11.0
# Tercer cuartil: 17.25
#
# --Valores extremos--
# Valor maximo: 23
# Valor minimo: 0
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  7    44
# 6    40
# 9    36
# Name: HORA_HECHO, dtype: int64
#
# --Valor maximo y minimo--
# Maximo: 23
# Minimo: 0

# %% [markdown]
# ### Columna TIPO_DE_CALLE

# %%
resources.informe_columna(df_unido, 'TIPO_DE_CALLE')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE TIPO_DE_CALLE:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 5
#
# --Valores unicos en la columna--
# ['AVENIDA' 'GRAL PAZ' 'CALLE' 'AUTOPISTA' 'SD']
#
# --Moda de la columna especificada--
# Valor modal -----> AVENIDA
# Frecuencia acumulada ------> 429
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  AVENIDA      429
# CALLE        136
# AUTOPISTA     65
# Name: TIPO_DE_CALLE, dtype: int64

# %% [markdown]
# ### Columna CRUCE

# %%
resources.informe_columna(df_unido, 'CRUCE')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE CRUCE:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 2
#
# --Valores unicos en la columna--
# ['SI' 'NO']
#
# --Moda de la columna especificada--
# Valor modal -----> SI
# Frecuencia acumulada ------> 524
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  SI    524
# NO    172
# Name: CRUCE, dtype: int64

# %% [markdown]
# ### Columna COMUNA

# %%
resources.informe_columna(df_unido, 'COMUNA')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE COMUNA:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 17
#
# --Valores unicos en la columna (Primeros 5 valores)--
# ['8' '9' '1' '11' '15']
#
# --Moda de la columna especificada--
# Valor modal -----> 1
# Frecuencia acumulada ------> 89
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  1    89
# 4    76
# 9    72
# Name: COMUNA, dtype: int64

# %% [markdown]
# ### Columna PARTICIPANTES

# %%
resources.informe_columna(df_unido, 'PARTICIPANTES')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE PARTICIPANTES:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 42
#
# --Valores unicos en la columna (Primeros 5 valores)--
# ['MOTO-AUTO' 'AUTO-PASAJEROS' 'MOTO-SD' 'MOTO-PASAJEROS'
#  'MOTO-OBJETO FIJO']
#
# --Moda de la columna especificada--
# Valor modal -----> PEATON-PASAJEROS
# Frecuencia acumulada ------> 105
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  PEATON-PASAJEROS    105
# MOTO-AUTO            83
# MOTO-CARGAS          78
# Name: PARTICIPANTES, dtype: int64

# %% [markdown]
# ### Columna VICTIMA

# %%
resources.informe_columna(df_unido, 'VICTIMA')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE VICTIMA:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 10
#
# --Valores unicos en la columna (Primeros 5 valores)--
# ['MOTO' 'AUTO' 'PEATON' 'SD' 'CARGAS']
#
# --Moda de la columna especificada--
# Valor modal -----> MOTO
# Frecuencia acumulada ------> 293
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  MOTO      293
# PEATON    264
# AUTO       83
# Name: VICTIMA, dtype: int64

# %% [markdown]
# ### Columna ACUSADO

# %%
resources.informe_columna(df_unido, 'ACUSADO')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE ACUSADO:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 10
#
# --Valores unicos en la columna (Primeros 5 valores)--
# ['AUTO' 'PASAJEROS' 'SD' 'OBJETO FIJO' 'CARGAS']
#
# --Moda de la columna especificada--
# Valor modal -----> AUTO
# Frecuencia acumulada ------> 204
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  AUTO         204
# PASAJEROS    173
# CARGAS       146
# Name: ACUSADO, dtype: int64

# %% [markdown]
# ### Columna EDAD

# %%
resources.informe_columna(df_unido, 'EDAD')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE EDAD:
#
# --Numero de datos nulos--
# 0
#
# --Valores unicos en la columna--
# Ej: [19 70 30 18 29]  -----> Desde 19  Hasta 88
#
# --Estadisticos Principales de la columna--
# Media: 42.37
# Desviacion Estandar: 19.09
# Primer cuartil: 28.0
# Mediana: 39.0
# Tercer cuartil: 55.0
#
# --Valores extremos--
# Valor maximo: 95
# Valor minimo: 1
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  42    58
# 30    24
# 29    24
# Name: EDAD, dtype: int64
#
# --Valor maximo y minimo--
# Maximo: 95
# Minimo: 1

# %% [markdown]
# ### Columna N_VICTIMAS

# %%
resources.informe_columna(df_unido, 'N_VICTIMAS')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE N_VICTIMAS:
#
# --Numero de datos nulos--
# 0
#
# --Valores unicos en la columna--
# Ej: [1 2 3]  -----> Desde 1  Hasta 3
#
# --Estadisticos Principales de la columna--
# Media: 1.03
# Desviacion Estandar: 0.18
# Primer cuartil: 1.0
# Mediana: 1.0
# Tercer cuartil: 1.0
#
# --Valores extremos--
# Valor maximo: 3
# Valor minimo: 1
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  1    676
# 2     19
# 3      1
# Name: N_VICTIMAS, dtype: int64
#
# --Valor maximo y minimo--
# Maximo: 3
# Minimo: 1

# %% [markdown]
# ### Columna PARTICIPANTES

# %%
resources.informe_columna(df_unido, 'PARTICIPANTES')
# Out:
# INFORME PRELIMINAR SOBRE LA COLUMNAS/FEATURE PARTICIPANTES:
#
# --Numero de datos nulos--
# 0
#
# --Cantidad de valores unicos en la columna--
# 42
#
# --Valores unicos en la columna (Primeros 5 valores)--
# ['MOTO-AUTO' 'AUTO-PASAJEROS' 'MOTO-SD' 'MOTO-PASAJEROS'
#  'MOTO-OBJETO FIJO']
#
# --Moda de la columna especificada--
# Valor modal -----> PEATON-PASAJEROS
# Frecuencia acumulada ------> 105
#
# --Distribucion de frecuencias (primeros valores con mayor cantidad de frecuencias)--
#  PEATON-PASAJEROS    105
# MOTO-AUTO            83
# MOTO-CARGAS          78
# Name: PARTICIPANTES, dtype: int64

# %% [markdown]
# # ANALISIS EXPLORATORIO DE ACCIDENTES FATALES

# %% [markdown]
# Buscamos patrones en la distribucion de los datos

# %% [markdown]
# ## DISTRIBUCION MENSUAL

# %%
resources.distribucion_anual_mensual(df_unido,'accidentes')

# %%
resources.distribucion_anual_mensual_x_media(df_unido)

# %%
resources.accidentes_anuales(df_unido)

# %% [markdown]
# Estos graficos refieren a la distribucion de victimas fatales por mes segun el año analizado y a la distribucion de accidentes fatales por mes segun el año analizado
# Podemos identificar la baja pronunciada en la cantidad de accidentes durante la mayoria del año 2020, atribuible a la cuarentena impuesta por COVID 18 (20 de marzo 2020--31 de enero 2021), aunque en la zona del AMBA en el mes de noviembre se paso a una etapa de distanciamiento social, por lo que se habilitaba la circulacion sin restriccion, lo que se ve reflejada en el repunte de accidentes con victimas fatales a finales de 2020 y principios de 2021 con una nueva caida pronunciada a causa del repunte de casos de COVID 18 y la consecuente nuevas restricciones a la circulacion impuestas por el gobierno de la ciudad en el mes de marzo
#
# Tambien podemos ver ciertos puntos en donde se marca una tendencia recurrente:
# * Desde el mes de diciembre a enero se observa una pendiente descendente en la cantidad de accidentes en la gran mayoria de los años
# * Ocurre algo similar en el lapso enero-febrero
# * Observamos que la gran mayoria de los años, entre el mes de julio-agosto existe un repunte de accidentes
#
# Vemos que ya desde el año 2018, existe una tendencia a la  baja en el numero de accidentes, por lo que debemos analizar los factores que cambiaron en ese lapso con respecto a los periodos anteriores (tomar en cuenta que el año 2020 fue el año de la cuarentena por COVID 18)

# %%
resources.cantidad_accidentes_mensuales(df_unido)
# REVISAR grafico de torta
# Out:
# El mes con menor cantidad de accidentes tiene 47 accidentes
# El mes con mayor cantidad de accidentes tiene 78 accidentes

# %% [markdown]
# Este grafico nos muestra la distribucion por mes del año de los accidentes fatales, podemos ver el valor maximo en el mes de diciembre, con consecuente caida y paulantino repunte hasta el mes de marzo. Ocurre algo similar en el mes de agosto con un repunte de los accidentes fatales, y una posterior baja paulatina hasta el mes de octubre donde se produce un nuevo repunte hasta llegar al maximo anual en el mes de diciembre.
#
# Podemos señalar como potencial patron el inicio de actividades ,tanto productivas como escolares, y de vacaciones como puntos de variabilidad, con su maximo exponente en las fiestas de fin de año.

# %%
resources.cantidad_por_dia_semana(df_unido,'accidentes')
# Out:
# El día de la semana con menor cantidad de accidentes tiene 94 víctimas
# El día de la semana con mayor cantidad de accidentes tiene 107 víctimas
# La diferencia porcentual es de 13.83

# %%
resources.cantidad_por_dia_semana(df_unido, 'victimas')
# Out:
# El día de la semana con menor cantidad de víctimas tiene 96 víctimas
# El día de la semana con mayor cantidad de víctimas tiene 108 víctimas
# La diferencia porcentual es de 12.5

# %% [markdown]
# Vemos que no existe una diferencia sustancial en la cantidad de accidentes segun el dia de la semana, lo que no nos permite obsevar algun tipo de patron relevante.

# %%
resources.cantidad_accidentes_por_categoria_tiempo(df_unido)
# Out:
# Franja horaria:
# Mañana: de 6:00 am a 10:59 am
# Mediodia: de 11 am a 13:59 pm
# Tarde: de 14 a 18:59 pm
# Noche: de 19 pm a 23:59 pm
# Madrugada: de 0 am a 5:59 am

# %% [markdown]
# A diferencia del grafico anterior, aqui vemos de manera marcada una gran diferencia en la cantidad de accidentes segun el momento del dia, esto marca ciertos patrones en cuanto a las actividades diarias que inciden en la generacion de accidentes.
# Por ejemplo podemos pensar que la franja horaria de la mañana es el momento en que mas accidentes se producen, se debe a las reactivaciones en los distintos estratos sociales y etareos de actividades que se producen en ella (horario comercial, laboral, de instituciones educativas, industrial, etc), como asi tambien la franja horaria del mediodia es el momento del dia donde en general la gente almuerza y aun continuan la mayoria de las actividades productivas, laborales, etc, por lo que hay un bajo desplazamiento de la gente.

# %% [markdown]
# DISTRIBUCION DE EDAD

# %% [markdown]
# Veamos la distribucion de la edad de las victimas

# %%
resources.distribucion_edad(df_unido)

# %% [markdown]
# Podemos ver que en gran parte, la edad de la mayoria de las victimas se encuentra en torno al rango de 20-40 años, con un 75% del total por debajo de los 55 años, con un una mediana de
# alrededor de los 39 años.
# No exiten valores atipicos, y podemos suponer que el rango de observaciones con edad menor a los 18 años, se componen principalmente de acompañantes,peatones y pasajeros (basicamente de todos los roles que no intervienen directamente en el manejo de un vehiculo) y ciclistas(vehiculo en el cual pueden manejar menores de edad)

# %%
resources.distribucion_edad_por_anio(df_unido)

# %% [markdown]
# No existen grandes diferencias en la distribucion de la edad de las personas por cada año, vemos que la mediana de todas las distribuciones es de alrededor de 40 años, y podemos ver algunos valores atipicos en los años 2016,2017 y 2019
#
# Veamos la edad en relacion al rol tomado en el siniestro.

# %%
resources.edad_y_rol_victimas(df_unido)

# %% [markdown]
# Vemos que la distribucion de conductores coincide con la edad habilitada para conducir y el 75% aprox se encuentra entre los 18 y los 40 años, y vemos la gran dispersion en la edad de los peatones, desde una edad muy joven hasta mayores ancianos
#
# Si bien en conductor y pasajero acompañante se observan algunos valores atípicos, los mismos son edades esperables y se consideran casos especiales en el conjunto de datos.

# %%
resources.distribucion_edad_por_victima(df_unido)

# %% [markdown]
# En este grafico se representa la distribucion de la edad de las victimas/acusados segun el vehiculo/medio de traslado que usaban al momento del siniestro
#
# De aqui podemos sacar algunas conclusiones:
# * El valor OBJETO FIJO es probable haga referencia a alguna instalacion, delimitacion, inmueble... y su participacion en el siniestro (obviamente como papel de 'victima' ya que resulta un poco ilogico que tenga el papel de acusado a menos que ocurran causas naturales, eventos de fuerza mayor, etc..), podemos encararlo desde esta perspectiva y con este juicio ya que este valor no se encuentra en el diccionario de datos. por lo que podemos considerar que la victima se encontraba dentro de alguna instalacion, o inmueble al momento del siniestro (por ejemplo, algun comercio, o alguna garita de omnibus)
# La definicion en nuestro diccionario de datos para este valor, pero referido a otra columna es: ""Colisión contra objetos inmóviles fijados de manera permanente o semipermanente (columna, árbol, semáforo, etc.) o pérdidas de equilibrio de vehículos de dos ruedas que desencadenen la caída de sus ocupantes"", por lo que es logico considerar estas situaciones y las descritas con anterioridad como plausibles
# * Vemos una amplia dispersion de edades en el valor peaton, y una concentracion pronunciada de victimas en el rol de pasajeros en el rango de 60 a 80 años. En el caso de victimas peatones es donde se observa un rango mas amplio de edades que en las demás categorías. Las victimas de mayor edad se observan mas concentradas cuando son pasajeros y victimas mas joven se observan en moto, objeto fijo y otros.

# %%
resources.cantidad_accidentes_finde(df_unido)

# %% [markdown]
# Aqui graficamos la cantidad de accidentes agrupandolos en dias de semana y fin de semana, podemos ver que no existe una diferencia significativa o un patron relevante de analisis,
# ya que a pesar de contar con una frecuencia acumulada mayor en el caso de dias de semana, se acumulan 5 dias en relacion a los 2 dias del fin de semana, si agrupamos la totalidad de
# accidente y los dividimos por el total de dias, nos daria alrededor de 102 accidentes por dia....

# %%
resources.cantidades_accidentes_por_anio_y_sexo(df_unido)

# %% [markdown]
# Este grafico nos muestra la cantidad de accidentes por año, segmentado segun el sexo de la victima
#
# Podemos ver una gran diferencia en la cantidad de mujeres y hombres, en todos los años. El año 2016 fue el año en que la diferencia fue mayor, y podemos ver la disminucion total en el año 2020 (a causa de la restriccion de circulacion por cuarentena de COVID 18).
#
# Aqui podemos ver una clara disminucion en la cantidad de accidentes a partir del año 2019 que continua hasta el año 2021 (existe un repunte entre el año 2020-2021 a causa de la cuarentena)

# %%
resources.cantidad_victimas_sexo_rol_victima(df_unido)

# %% [markdown]
# En estos graficos, se puede ver la diferencia en la cantidad de víctimas masculina por sobre las femeninas. Se aprecia la diferencia sobre todo en Conductor, donde la mayor proporción son masculinos y lo que llama la atención es que Motos es el vehículo con mayor proporción de accidentes con una alta proporción de masculinos. Los peatones también son las víctimas con mayor cantidad de fallecimientos en accidentes, con mayor proporción de masculinos, pero con una diferencia menos pronunciada.

# %%
resources.cantidad_victimas_participantes(df_unido)

# %% [markdown]
# Este grafico analiza la cantidad de victimas segun los participantes que intervinieron en el siniestro
#
# Aqui podemos ver que las 5 primeras categorias agrupan mas del 55% del total de victimas fatales, habiendo una gran diferencia entre las primeras 4 con el resto.
# La primera categoria refiere a PEATON-PASAJEROS, teniendo al peaton como victima y al pasajero como acusado. Podemos decir que este tipo de siniestro hace referencia a vehiculos o transportes de pasajeros, como por ejemplo el transporte publico de pasajeros (colectivos, trolebus, etc) o transportes de pasajeros turisticos que cumplen un rol similar (aunque con finalidad diferente), con peatones
#
# Tambien es importante destacar que los roles de PEATON y MOTO estan presentes en todas las combinaciones que mas victimas tienen, esto complementa el grafico anterior en donde veiamos que el rol MOTO era el que mas victimas fatales tenia, seguido de el rol PEATON

# %%
resources.cantidad_acusados(df_unido)

# %% [markdown]
# Este grafico nos muestra la distribucion de los acusados en cada siniestro. Existe una gran concentracion de acusados que se movilizaban en auto (mas del 29%), seguidos por el valor PASAJEROS (que recordemos hace referencia a transporte urbano de pasajeros como los omnibus) y por cargas (vehiculos de transporte de cargas, como camiones) con casi el 25% y el 21% respectivamente.
#
# podemos ver que las 3 primeras categorias son practicamente casi el 75% de los casos de acusados, que tambien podriamos llamar responsables del siniestro a la practica (sin implicancia legal).

# %%
resources.accidentes_tipo_de_calle(df_unido)

# %% [markdown]
# Este grafico nos muestra la distribucion de accidentes con victimas fatales segun el tipo de calle donde se produjo el siniestro.
#
# Vemos que existe una clara concentracion de estos accidentes en las avenidas, siendo mas del 61% ocurridas en estas, y del resto casi el 20% ocurrieron en calles...
#
# Caso especial es el de la Avenida General Paz, ya que la tomamos como una categoria propia (aunque pertenezca a la categoria de avenidas), pero en caso contrario, estariamos hablando de mas de un 71% de accidentes de transito/siniestros vehiculares con victimas fatales que se producen en avenidas de la ciudad.

# %%
resources.accidentes_cruce(df_unido)

# %% [markdown]
# Estos graficos nos muestran que existe una amplia cantidad (más del 75%) de los accidentes que ocurren en los cruces de CABA, sumado a esto que mas del 71% de los accidentes ocurren en Avenidas, podemos decir que aproximadamente 3 de cada 4 accidentes que ocurren Ciudad de Bs As se producen en la interseccion con una avenida (o entre avenidas).
#
# Complementando esto, vemos que las franjas horarias que van desde la noche hasta la mañana presentan una amplia diferencia en cantidades de accidentes en cruces en comparacion con los accidentes que no son en cruces en estos horarios, asimismo si lo comparamos con otras franjas horarias.
#
# Esto nos insinua que mas allá de que la franja horaria de la mañana es la que presenta mayor cantidad de accidentes, las franjas horarias laborales (mediodia, tarde, y parte de la mañana), son los que ocrurren menos accidentes en cruces en proporcion con las demas franjas horarias (noche, madrugada, parte de la mañana)

# %%
resources.cruces_x_momentos(df_unido)

# %% [markdown]
# Esto confirma que las franjas horarias en donde más accidentes ocurren, más proporcion de accidentes en cruces se producen en proporcion del total acaecido.
